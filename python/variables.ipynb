# %%
x=5
name = 'alex'
print(x)
print(name)
# Out:
# 5
# alex

# %%
a,b,c=10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %%
#Type casting
x=20.0
x=int(x)
print(x)
# Out:
# 20

# %%
#types of variable
x=10
y=2.5
z='hello'
a=[1,2,3]
b={'key':'value'}
bool=True

print(type(x))
print(type(y))
print(type(z))
print(type(a))
print(type(b))
print(type(bool))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'bool'>

# %%
#delete a variable
x = 10
y=20
del x
print(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 y=20
#       4 del x
# ----> 5 print(x,y)
#
# NameError: name 'x' is not defined

# %%
#swap the values
a,b=10,20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
#count char in a string
str='python'
length=len(str)
print(length)
# Out:
# 6

# %%
#I/0
name=input('Enter your name: ')
print('Hello', name)
# Out:
# Enter your name:  Alex
# Hello Alex

# %%
#multiple inputs
x, y = input("Enter two values: ").split()
print("value 1: ", x)
print("value 2: ", y)
print('combining both values: ',x + y)
# Out:
# Enter two values:  Hello Ashish
# value 1:  Hello
# value 2:  Ashish
# combining both values:  HelloAshish
