# %%
type(list1)
# Out:
# list

# %%
list2=['king', 'queen','rock',22 ,22.5]

# %%
print(list2[1])
# Out:
# queen

# %%
print(list2[-1])
# Out:
# 22.5

# %%
print(list2[1:3])
# Out:
# ['queen', 'rock']

# %%
print(list2[1:])
# Out:
# ['queen', 'rock', 22, 22.5]

# %%
print(list2[:3])
# Out:
# lea
